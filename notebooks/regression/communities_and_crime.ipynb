# %% [markdown]
# # Communities and Crime
# ## Description
#
# Data set of various american communities containing their attributes such as population, median income, parental divorce rates, etc.. The data is a combination of the following banks of information :
# - 1990 US Census
# - law enforcement data from the 1990 US LEMAS survey
# - and crime data from the 1995 FBI UCR.
#
# The column attributes are as follows:
#
# | Attribute |Domain |
# | ----------- |----------- |
# | state | 0 - 1 |
# | county | 0 - 1 |
# | community | 0 - 1 |
# | communityname| string |
# | fold | 0 - 1 |
# | population | 0 - 1 |
# | householdsize | 0 - 1 |
# | racepctblack | 0 - 1 |
# | racePctWhite | 0 - 1 |
# | racePctAsian | 0 - 1 |
# | racePctHisp | 0 - 1 |
# | agePct12t21 | 0 - 1 |
# | agePct12t29 | 0 - 1 |
# | agePct16t24 | 0 - 1 |
# | agePct65up | 0 - 1 |
# | numbUrban | 0 - 1 |
# | pctUrban | 0 - 1 |
# | medIncome | 0 - 1 |
# | pctWWage | 0 - 1 |
# | pctWFarmSelf | 0 - 1 |
# | pctWInvInc | 0 - 1 |
# | pctWSocSec | 0 - 1 |
# | pctWPubAsst | 0 - 1 |
# | pctWRetire | 0 - 1 |
# | medFamInc | 0 - 1 |
# | perCapInc | 0 - 1 |
# | whitePerCap | 0 - 1 |
# | blackPerCap | 0 - 1 |
# | indianPerCap | 0 - 1 |
# | AsianPerCap | 0 - 1 |
# | OtherPerCap | 0 - 1 |
# | HispPerCap | 0 - 1 |
# | NumUnderPov | 0 - 1 |
# | PctPopUnderPov | 0 - 1 |
# | PctLess9thGrade | 0 - 1 |
# | PctNotHSGrad | 0 - 1 |
# | PctBSorMore | 0 - 1 |
# | PctUnemployed | 0 - 1 |
# | PctEmploy | 0 - 1 |
# | PctEmplManu | 0 - 1 |
# | PctEmplProfServ | 0 - 1 |
# | PctOccupManu | 0 - 1 |
# | PctOccupMgmtProf | 0 - 1 |
# | MalePctDivorce | 0 - 1 |
# | MalePctNevMarr | 0 - 1 |
# | FemalePctDiv | 0 - 1 |
# | TotalPctDiv | 0 - 1 |
# | PersPerFam | 0 - 1 |
# | PctFam2Par | 0 - 1 |
# | PctKids2Par | 0 - 1 |
# | PctYoungKids2Par | 0 - 1 |
# | PctTeen2Par | 0 - 1 |
# | PctWorkMomYoungKids | 0 - 1 |
# | PctWorkMom | 0 - 1 |
# | NumIlleg | 0 - 1 |
# | PctIlleg | 0 - 1 |
# | NumImmig | 0 - 1 |
# | PctImmigRecent | 0 - 1 |
# | PctImmigRec5 | 0 - 1 |
# | PctImmigRec8 | 0 - 1 |
# | PctImmigRec10 | 0 - 1 |
# | PctRecentImmig | 0 - 1 |
# | PctRecImmig5 | 0 - 1 |
# | PctRecImmig8 | 0 - 1 |
# | PctRecImmig10 | 0 - 1 |
# | PctSpeakEnglOnly | 0 - 1 |
# | PctNotSpeakEnglWell | 0 - 1 |
# | PctLargHouseFam | 0 - 1 |
# | PctLargHouseOccup | 0 - 1 |
# | PersPerOccupHous | 0 - 1 |
# | PersPerOwnOccHous | 0 - 1 |
# | PersPerRentOccHous | 0 - 1 |
# | PctPersOwnOccup | 0 - 1 |
# | PctPersDenseHous | 0 - 1 |
# | PctHousLess3BR | 0 - 1 |
# | MedNumBR | 0 - 1 |
# | HousVacant | 0 - 1 |
# | PctHousOccup | 0 - 1 |
# | PctHousOwnOcc | 0 - 1 |
# | PctVacantBoarded | 0 - 1 |
# | PctVacMore6Mos | 0 - 1 |
# | MedYrHousBuilt | 0 - 1 |
# | PctHousNoPhone | 0 - 1 |
# | PctWOFullPlumb | 0 - 1 |
# | OwnOccLowQuart | 0 - 1 |
# | OwnOccMedVal | 0 - 1 |
# | OwnOccHiQuart | 0 - 1 |
# | RentLowQ | 0 - 1 |
# | RentMedian | 0 - 1 |
# | RentHighQ | 0 - 1 |
# | MedRent | 0 - 1 |
# | MedRentPctHousInc | 0 - 1 |
# | MedOwnCostPctInc | 0 - 1 |
# | MedOwnCostPctIncNoMtg | 0 - 1 |
# | NumInShelters | 0 - 1 |
# | NumStreet | 0 - 1 |
# | PctForeignBorn | 0 - 1 |
# | PctBornSameState | 0 - 1 |
# | PctSameHouse85 | 0 - 1 |
# | PctSameCity85 | 0 - 1 |
# | PctSameState85 | 0 - 1 |
# | LemasSwornFT | 0 - 1 |
# | LemasSwFTPerPop | 0 - 1 |
# | LemasSwFTFieldOps | 0 - 1 |
# | LemasSwFTFieldPerPop | 0 - 1 |
# | LemasTotalReq | 0 - 1 |
# | LemasTotReqPerPop | 0 - 1 |
# | PolicReqPerOffic | 0 - 1 |
# | PolicPerPop | 0 - 1 |
# | RacialMatchCommPol | 0 - 1 |
# | PctPolicWhite | 0 - 1 |
# | PctPolicBlack | 0 - 1 |
# | PctPolicHisp | 0 - 1 |
# | PctPolicAsian | 0 - 1 |
# | PctPolicMinor | 0 - 1 |
# | OfficAssgnDrugUnits | 0 - 1 |
# | NumKindsDrugsSeiz | 0 - 1 |
# | PolicAveOTWorked | 0 - 1 |
# | LandArea | 0 - 1 |
# | PopDens | 0 - 1 |
# | PctUsePubTrans | 0 - 1 |
# | PolicCars | 0 - 1 |
# | PolicOperBudg | 0 - 1 |
# | LemasPctPolicOnPatr | 0 - 1 |
# | LemasGangUnitDeploy | 0 - 1 |
# | LemasPctOfficDrugUn | 0 - 1 |
# | PolicBudgPerPop | 0 - 1 |
# | ViolentCrimesPerPop | 0 - 1 |

# %% [markdown]
# ## Importing and processing dataset

# %%
import os                        # for os.path.exists
import json                      # for loading metadata
import urllib                    # for downloading remote files 
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
def download(remoteurl: str, localfile: str):
    """
    Download remoteurl to localfile, unless localfile already exists.
    Returns the localfile string.
    """
    localfile = "../../datasets/classification/"+localfile
    if not os.path.exists(localfile):
        print("Downloading %s..." % localfile)
        filename, headers = urllib.request.urlretrieve(remoteurl, localfile)
    return localfile

# %%
crime_data= download("http://archive.ics.uci.edu/ml/machine-learning-databases/communities/communities.data","crime-data")
headers = ["state",
"county",
"community",
"communityname",
"fold",
"population",
"householdsize",
"racepctblack",
"racePctWhite",
"racePctAsian",
"racePctHisp",
"agePct12t21",
"agePct12t29",
"agePct16t24",
"agePct65up",
"numbUrban",
"pctUrban",
"medIncome",
"pctWWage",
"pctWFarmSelf",
"pctWInvInc",
"pctWSocSec",
"pctWPubAsst",
"pctWRetire",
"medFamInc",
"perCapInc",
"whitePerCap",
"blackPerCap",
"indianPerCap",
"AsianPerCap",
"OtherPerCap",
"HispPerCap",
"NumUnderPov",
"PctPopUnderPov",
"PctLess9thGrade",
"PctNotHSGrad",
"PctBSorMore",
"PctUnemployed",
"PctEmploy",
"PctEmplManu",
"PctEmplProfServ",
"PctOccupManu",
"PctOccupMgmtProf",
"MalePctDivorce",
"MalePctNevMarr",
"FemalePctDiv",
"TotalPctDiv",
"PersPerFam",
"PctFam2Par",
"PctKids2Par",
"PctYoungKids2Par",
"PctTeen2Par",
"PctWorkMomYoungKids",
"PctWorkMom",
"NumIlleg",
"PctIlleg",
"NumImmig",
"PctImmigRecent",
"PctImmigRec5",
"PctImmigRec8",
"PctImmigRec10",
"PctRecentImmig",
"PctRecImmig5",
"PctRecImmig8",
"PctRecImmig10",
"PctSpeakEnglOnly",
"PctNotSpeakEnglWell",
"PctLargHouseFam",
"PctLargHouseOccup",
"PersPerOccupHous",
"PersPerOwnOccHous",
"PersPerRentOccHous",
"PctPersOwnOccup",
"PctPersDenseHous",
"PctHousLess3BR",
"MedNumBR",
"HousVacant",
"PctHousOccup",
"PctHousOwnOcc",
"PctVacantBoarded",
"PctVacMore6Mos",
"MedYrHousBuilt",
"PctHousNoPhone",
"PctWOFullPlumb",
"OwnOccLowQuart",
"OwnOccMedVal",
"OwnOccHiQuart",
"RentLowQ",
"RentMedian",
"RentHighQ",
"MedRent",
"MedRentPctHousInc",
"MedOwnCostPctInc",
"MedOwnCostPctIncNoMtg",
"NumInShelters",
"NumStreet",
"PctForeignBorn",
"PctBornSameState",
"PctSameHouse85",
"PctSameCity85",
"PctSameState85",
"LemasSwornFT",
"LemasSwFTPerPop",
"LemasSwFTFieldOps",
"LemasSwFTFieldPerPop",
"LemasTotalReq",
"LemasTotReqPerPop",
"PolicReqPerOffic",
"PolicPerPop",
"RacialMatchCommPol",
"PctPolicWhite",
"PctPolicBlack",
"PctPolicHisp",
"PctPolicAsian",
"PctPolicMinor",
"OfficAssgnDrugUnits",
"NumKindsDrugsSeiz",
"PolicAveOTWorked",
"LandArea",
"PopDens",
"PctUsePubTrans",
"PolicCars",
"PolicOperBudg",
"LemasPctPolicOnPatr",
"LemasGangUnitDeploy",
"LemasPctOfficDrugUn",
"PolicBudgPerPop",
"ViolentCrimesPerPop" ]
crime_df = pd.read_csv(crime_data, header = None, names = headers)
crime_df.shape
# Out:
# (1994, 128)

# %%
crime_df = crime_df.drop(["county","community","communityname","fold"], axis=1)

# %%
for header in headers:
    if(header != "county" and header !="community" and header !="communityname" and header !="fold"):
        print(header)
        print(crime_df[header].value_counts())

crime_df = crime_df.replace({'?':np.nan}).dropna(axis='columns')
# Out:
# state
# 6     278
# 34    211
# 48    156
# 25    121
# 39    109
# 42    101
# 12     90
# 9      69
# 55     60
# 18     48
# 37     46
# 36     46
# 1      43
# 29     42
# 53     40
# 13     37
# 40     36
# 47     35
# 51     33
# 41     31
# 45     28
# 21     26
# 44     26
# 5      25
# 8      25
# 49     24
# 22     22
# 33     21
# 4      20
# 19     20
# 28     19
# 23     17
# 54     14
# 24     12
# 35     10
# 46      9
# 38      8
# 16      7
# 27      7
# 56      7
# 32      5
# 50      4
# 2       3
# 20      1
# 11      1
# 10      1
# Name: state, dtype: int64
# population
# 0.01    454
# 0.00    385
# 0.02    271
# 0.03    193
# 0.04    121
#        ...
# 0.99      1
# 0.91      1
# 0.73      1
# 0.60      1
# 0.42      1
# Name: population, Length: 66, dtype: int64
# householdsize
# 0.41    76
# 0.39    69
# 0.35    68
# 0.37    67
# 0.33    65
#         ..
# 0.86     1
# 0.91     1
# 0.85     1
# 0.08     1
# 0.82     1
# Name: householdsize, Length: 93, dtype: int64
# racepctblack
# 0.01    285
# 0.02    236
# 0.03    141
# 0.00    134
# 0.04     86
#        ...
# 0.98      1
# 0.73      1
# 0.80      1
# 0.99      1
# 0.94      1
# Name: racepctblack, Length: 100, dtype: int64
# racePctWhite
# 0.98    122
# 0.96     99
# 0.97     96
# 0.99     82
# 0.95     81
#        ...
# 0.16      2
# 0.05      2
# 0.26      2
# 0.06      1
# 0.15      1
# Name: racePctWhite, Length: 99, dtype: int64
# racePctAsian
# 0.02    191
# 0.03    175
# 0.04    168
# 0.05    144
# 0.06    121
#        ...
# 0.89      1
# 0.94      1
# 0.70      1
# 0.68      1
# 0.73      1
# Name: racePctAsian, Length: 91, dtype: int64
# racePctHisp
# 0.01    446
# 0.02    254
# 0.03    158
# 0.04    124
# 0.05     95
#        ...
# 0.93      1
# 0.81      1
# 0.70      1
# 0.71      1
# 0.61      1
# Name: racePctHisp, Length: 91, dtype: int64
# agePct12t21
# 0.38    93
# 0.41    93
# 0.40    90
# 0.39    89
# 0.36    83
#         ..
# 0.78     1
# 0.79     1
# 0.10     1
# 0.03     1
# 0.12     1
# Name: agePct12t21, Length: 93, dtype: int64
# agePct12t29
# 0.49    90
# 0.46    87
# 0.48    87
# 0.50    80
# 0.41    79
#         ..
# 0.99     1
# 0.00     1
# 0.03     1
# 0.18     1
# 0.05     1
# Name: agePct12t29, Length: 89, dtype: int64
# agePct16t24
# 0.29    118
# 0.26    115
# 0.28    114
# 0.27    110
# 0.30    105
#        ...
# 0.94      1
# 0.07      1
# 0.05      1
# 0.83      1
# 0.96      1
# Name: agePct16t24, Length: 94, dtype: int64
# agePct65up
# 0.47    59
# 0.35    49
# 0.33    49
# 0.52    49
# 0.42    48
#         ..
# 0.89     1
# 0.99     1
# 0.02     1
# 0.95     1
# 0.01     1
# Name: agePct65up, Length: 98, dtype: int64
# numbUrban
# 0.00    568
# 0.02    329
# 0.03    193
# 0.04    149
# 0.05    124
#        ...
# 0.82      1
# 0.68      1
# 0.63      1
# 0.64      1
# 0.43      1
# Name: numbUrban, Length: 67, dtype: int64
# pctUrban
# 1.00    1193
# 0.00     558
# 0.99      23
# 0.98      20
# 0.97      15
#         ...
# 0.65       1
# 0.05       1
# 0.07       1
# 0.39       1
# 0.02       1
# Name: pctUrban, Length: 64, dtype: int64
# medIncome
# 0.23    74
# 0.16    67
# 0.17    66
# 0.25    54
# 0.22    52
#         ..
# 0.00     1
# 0.98     1
# 0.99     1
# 0.97     1
# 0.03     1
# Name: medIncome, Length: 99, dtype: int64
# pctWWage
# 0.58    52
# 0.53    52
# 0.49    51
# 0.60    49
# 0.57    48
#         ..
# 0.15     2
# 0.96     1
# 0.01     1
# 0.97     1
# 0.08     1
# Name: pctWWage, Length: 96, dtype: int64
# pctWFarmSelf
# 0.16    74
# 0.17    73
# 0.19    69
# 0.18    69
# 0.22    64
#         ..
# 0.69     1
# 0.93     1
# 0.90     1
# 0.79     1
# 0.92     1
# Name: pctWFarmSelf, Length: 99, dtype: int64
# pctWInvInc
# 0.41    55
# 0.46    54
# 0.48    52
# 0.39    46
# 0.38    46
#         ..
# 0.11     1
# 0.02     1
# 0.95     1
# 0.06     1
# 0.97     1
# Name: pctWInvInc, Length: 96, dtype: int64
# pctWSocSec
# 0.56    62
# 0.51    49
# 0.46    49
# 0.53    48
# 0.52    48
#         ..
# 0.92     1
# 0.03     1
# 0.93     1
# 0.94     1
# 0.04     1
# Name: pctWSocSec, Length: 96, dtype: int64
# pctWPubAsst
# 0.10    70
# 0.12    57
# 0.16    55
# 0.21    50
# 0.17    49
#         ..
# 0.87     2
# 0.78     2
# 0.96     2
# 0.00     1
# 0.98     1
# Name: pctWPubAsst, Length: 101, dtype: int64
# pctWRetire
# 0.44    58
# 0.40    55
# 0.42    53
# 0.51    52
# 0.45    51
#         ..
# 0.98     1
# 0.10     1
# 0.96     1
# 0.97     1
# 0.07     1
# Name: pctWRetire, Length: 93, dtype: int64
# medFamInc
# 0.25    66
# 0.21    59
# 0.19    58
# 0.26    55
# 0.22    54
#         ..
# 0.04     2
# 0.00     1
# 0.87     1
# 0.02     1
# 0.93     1
# Name: medFamInc, Length: 98, dtype: int64
# perCapInc
# 0.23    74
# 0.22    73
# 0.24    68
# 0.21    66
# 0.25    63
#         ..
# 0.77     2
# 0.90     1
# 0.95     1
# 0.00     1
# 0.96     1
# Name: perCapInc, Length: 98, dtype: int64
# whitePerCap
# 0.30    69
# 0.20    66
# 0.28    66
# 0.32    63
# 0.25    62
#         ..
# 0.88     1
# 0.08     1
# 0.00     1
# 0.01     1
# 0.99     1
# Name: whitePerCap, Length: 101, dtype: int64
# blackPerCap
# 0.18    88
# 0.17    87
# 0.16    78
# 0.19    74
# 0.20    72
#         ..
# 0.92     1
# 0.93     1
# 0.87     1
# 0.95     1
# 0.02     1
# Name: blackPerCap, Length: 91, dtype: int64
# indianPerCap
# 0.00    166
# 0.16    101
# 0.15     88
# 0.11     85
# 0.13     82
#        ...
# 0.88      1
# 0.66      1
# 0.75      1
# 0.58      1
# 0.73      1
# Name: indianPerCap, Length: 86, dtype: int64
# AsianPerCap
# 0.18    68
# 0.23    61
# 0.25    61
# 0.26    60
# 0.27    58
#         ..
# 0.99     1
# 0.92     1
# 0.81     1
# 0.85     1
# 0.84     1
# Name: AsianPerCap, Length: 98, dtype: int64
# OtherPerCap
# 0       129
# 0.25     78
# 0.2      71
# 0.22     70
# 0.16     66
#        ...
# 0.71      1
# 0.83      1
# 0.82      1
# 0.65      1
# 0.89      1
# Name: OtherPerCap, Length: 98, dtype: int64
# HispPerCap
# 0.30    67
# 0.33    65
# 0.32    65
# 0.26    65
# 0.31    60
#         ..
# 0.08     1
# 0.82     1
# 0.04     1
# 0.10     1
# 0.97     1
# Name: HispPerCap, Length: 94, dtype: int64
# NumUnderPov
# 0.01    527
# 0.00    314
# 0.02    313
# 0.03    198
# 0.04    133
#        ...
# 0.59      1
# 0.56      1
# 0.30      1
# 0.37      1
# 0.82      1
# Name: NumUnderPov, Length: 66, dtype: int64
# PctPopUnderPov
# 0.08    70
# 0.07    61
# 0.05    61
# 0.10    57
# 0.09    56
#         ..
# 0.96     2
# 0.95     1
# 0.97     1
# 0.92     1
# 0.94     1
# Name: PctPopUnderPov, Length: 100, dtype: int64
# PctLess9thGrade
# 0.19    59
# 0.11    57
# 0.17    55
# 0.30    52
# 0.18    51
#         ..
# 0.00     1
# 0.90     1
# 0.86     1
# 0.84     1
# 0.91     1
# Name: PctLess9thGrade, Length: 97, dtype: int64
# PctNotHSGrad
# 0.39    50
# 0.19    49
# 0.15    45
# 0.29    42
# 0.22    42
#         ..
# 0.93     2
# 0.98     1
# 0.92     1
# 0.96     1
# 0.00     1
# Name: PctNotHSGrad, Length: 99, dtype: int64
# PctBSorMore
# 0.18    67
# 0.21    66
# 0.24    64
# 0.25    63
# 0.23    56
#         ..
# 0.00     2
# 0.82     2
# 0.83     1
# 0.85     1
# 0.02     1
# Name: PctBSorMore, Length: 96, dtype: int64
# PctUnemployed
# 0.24    56
# 0.22    52
# 0.32    50
# 0.27    49
# 0.25    49
#         ..
# 0.99     1
# 0.88     1
# 0.00     1
# 0.83     1
# 0.02     1
# Name: PctUnemployed, Length: 98, dtype: int64
# PctEmploy
# 0.56    56
# 0.58    52
# 0.51    51
# 0.50    49
# 0.52    49
#         ..
# 0.90     1
# 0.92     1
# 0.91     1
# 0.96     1
# 0.01     1
# Name: PctEmploy, Length: 96, dtype: int64
# PctEmplManu
# 0.26    52
# 0.30    48
# 0.36    47
# 0.39    47
# 0.27    45
#         ..
# 0.93     1
# 0.02     1
# 0.94     1
# 0.99     1
# 0.00     1
# Name: PctEmplManu, Length: 100, dtype: int64
# PctEmplProfServ
# 0.36    69
# 0.39    64
# 0.38    60
# 0.30    60
# 0.43    57
#         ..
# 0.95     1
# 0.08     1
# 0.01     1
# 0.98     1
# 0.07     1
# Name: PctEmplProfServ, Length: 96, dtype: int64
# PctOccupManu
# 0.32    51
# 0.34    45
# 0.45    45
# 0.39    45
# 0.42    44
#         ..
# 0.00     2
# 0.97     1
# 0.92     1
# 0.96     1
# 0.93     1
# Name: PctOccupManu, Length: 98, dtype: int64
# PctOccupMgmtProf
# 0.36    66
# 0.34    64
# 0.39    57
# 0.31    57
# 0.37    56
#         ..
# 0.97     1
# 0.11     1
# 0.89     1
# 0.00     1
# 0.10     1
# Name: PctOccupMgmtProf, Length: 99, dtype: int64
# MalePctDivorce
# 0.56    52
# 0.48    50
# 0.45    48
# 0.55    48
# 0.43    45
#         ..
# 0.86     1
# 0.00     1
# 0.91     1
# 0.95     1
# 0.98     1
# Name: MalePctDivorce, Length: 98, dtype: int64
# MalePctNevMarr
# 0.38    65
# 0.30    64
# 0.35    64
# 0.42    63
# 0.36    62
#         ..
# 0.03     1
# 0.08     1
# 0.10     1
# 0.89     1
# 0.82     1
# Name: MalePctNevMarr, Length: 96, dtype: int64
# FemalePctDiv
# 0.54    55
# 0.50    53
# 0.56    51
# 0.63    51
# 0.61    49
#         ..
# 0.06     1
# 0.87     1
# 0.90     1
# 0.05     1
# 0.07     1
# Name: FemalePctDiv, Length: 91, dtype: int64
# TotalPctDiv
# 0.57    52
# 0.54    49
# 0.61    48
# 0.48    46
# 0.64    45
#         ..
# 0.96     2
# 0.97     2
# 0.98     1
# 0.05     1
# 0.95     1
# Name: TotalPctDiv, Length: 94, dtype: int64
# PersPerFam
# 0.44    101
# 0.40    100
# 0.49     98
# 0.47     87
# 0.51     86
#        ...
# 0.13      1
# 0.09      1
# 0.15      1
# 0.89      1
# 0.91      1
# Name: PersPerFam, Length: 92, dtype: int64
# PctFam2Par
# 0.70    51
# 0.64    51
# 0.61    45
# 0.62    43
# 0.54    43
#         ..
# 0.04     1
# 0.09     1
# 0.02     1
# 0.03     1
# 0.07     1
# Name: PctFam2Par, Length: 101, dtype: int64
# PctKids2Par
# 0.72    47
# 0.59    46
# 0.76    46
# 0.68    44
# 0.67    43
#         ..
# 1.00     2
# 0.10     2
# 0.11     2
# 0.02     1
# 0.99     1
# Name: PctKids2Par, Length: 97, dtype: int64
# PctYoungKids2Par
# 0.91    49
# 0.88    47
# 0.86    44
# 0.71    44
# 0.87    42
#         ..
# 0.09     2
# 0.21     2
# 0.07     2
# 0.08     2
# 0.03     1
# Name: PctYoungKids2Par, Length: 99, dtype: int64
# PctTeen2Par
# 0.60    57
# 0.61    54
# 0.63    52
# 0.62    51
# 0.69    46
#         ..
# 0.04     2
# 0.11     1
# 0.97     1
# 0.07     1
# 0.08     1
# Name: PctTeen2Par, Length: 96, dtype: int64
# PctWorkMomYoungKids
# 0.51    63
# 0.52    61
# 0.48    55
# 0.55    52
# 0.49    51
#         ..
# 0.91     1
# 0.05     1
# 0.97     1
# 0.98     1
# 0.01     1
# Name: PctWorkMomYoungKids, Length: 95, dtype: int64
# PctWorkMom
# 0.57    64
# 0.54    59
# 0.49    56
# 0.52    54
# 0.60    52
#         ..
# 0.94     2
# 0.07     1
# 0.95     1
# 0.01     1
# 0.02     1
# Name: PctWorkMom, Length: 98, dtype: int64
# NumIlleg
# 0.00    750
# 0.01    543
# 0.02    206
# 0.03    134
# 0.04     65
# 0.05     49
# 0.06     41
# 0.07     24
# 0.09     21
# 0.08     17
# 0.11     16
# 0.10     11
# 1.00     11
# 0.13      9
# 0.12      9
# 0.16      6
# 0.18      4
# 0.22      4
# 0.47      4
# 0.37      4
# 0.14      4
# 0.20      4
# 0.34      3
# 0.23      3
# 0.49      3
# 0.15      3
# 0.27      3
# 0.17      3
# 0.29      3
# 0.19      3
# 0.55      2
# 0.39      2
# 0.72      2
# 0.41      2
# 0.28      2
# 0.45      2
# 0.43      2
# 0.24      2
# 0.36      2
# 0.38      1
# 0.78      1
# 0.62      1
# 0.35      1
# 0.97      1
# 0.61      1
# 0.93      1
# 0.59      1
# 0.74      1
# 0.21      1
# 0.32      1
# 0.67      1
# 0.26      1
# 0.42      1
# 0.30      1
# 0.77      1
# Name: NumIlleg, dtype: int64
# PctIlleg
# 0.09    86
# 0.06    79
# 0.08    78
# 0.04    73
# 0.05    68
#         ..
# 0.98     1
# 0.88     1
# 0.90     1
# 0.71     1
# 0.82     1
# Name: PctIlleg, Length: 97, dtype: int64
# NumImmig
# 0.00    826
# 0.01    496
# 0.02    216
# 0.03    100
# 0.04     68
# 0.05     43
# 0.06     34
# 0.07     31
# 0.08     21
# 0.09     20
# 0.14     15
# 0.10     13
# 0.13     12
# 0.16     10
# 0.11      9
# 0.15      9
# 1.00      7
# 0.12      7
# 0.20      6
# 0.18      5
# 0.21      4
# 0.17      3
# 0.23      3
# 0.34      3
# 0.28      3
# 0.27      3
# 0.32      2
# 0.22      2
# 0.70      2
# 0.24      2
# 0.29      2
# 0.19      2
# 0.59      1
# 0.54      1
# 0.30      1
# 0.25      1
# 0.57      1
# 0.41      1
# 0.49      1
# 0.58      1
# 0.81      1
# 0.26      1
# 0.84      1
# 0.38      1
# 0.77      1
# 0.45      1
# 0.39      1
# Name: NumImmig, dtype: int64
# PctImmigRecent
# 0.00    114
# 0.27     50
# 0.33     49
# 0.29     45
# 0.25     45
#        ...
# 0.77      1
# 0.85      1
# 0.99      1
# 0.91      1
# 0.92      1
# Name: PctImmigRecent, Length: 99, dtype: int64
# PctImmigRec5
# 0.00    51
# 0.42    50
# 0.33    44
# 0.48    44
# 0.32    42
#         ..
# 0.96     1
# 0.84     1
# 0.82     1
# 0.99     1
# 0.87     1
# Name: PctImmigRec5, Length: 100, dtype: int64
# PctImmigRec8
# 0.26    46
# 0.36    44
# 0.39    43
# 0.45    43
# 0.50    41
#         ..
# 0.83     2
# 0.91     1
# 0.97     1
# 0.87     1
# 0.01     1
# Name: PctImmigRec8, Length: 97, dtype: int64
# PctImmigRec10
# 0.43    49
# 0.45    45
# 0.44    45
# 0.47    44
# 0.28    43
#         ..
# 0.90     2
# 0.99     2
# 0.98     1
# 0.93     1
# 0.02     1
# Name: PctImmigRec10, Length: 97, dtype: int64
# PctRecentImmig
# 0.01    155
# 0.03    147
# 0.00    140
# 0.02    138
# 0.05     95
#        ...
# 0.87      2
# 0.92      1
# 0.95      1
# 0.94      1
# 0.97      1
# Name: PctRecentImmig, Length: 95, dtype: int64
# PctRecImmig5
# 0.02    176
# 0.01    161
# 0.03    144
# 0.04    118
# 0.06     92
#        ...
# 0.90      1
# 0.45      1
# 0.87      1
# 0.98      1
# 0.79      1
# Name: PctRecImmig5, Length: 97, dtype: int64
# PctRecImmig8
# 0.02    170
# 0.03    160
# 0.01    145
# 0.04    108
# 0.05    106
#        ...
# 0.95      1
# 0.66      1
# 0.86      1
# 0.92      1
# 0.91      1
# Name: PctRecImmig8, Length: 98, dtype: int64
# PctRecImmig10
# 0.02    171
# 0.01    148
# 0.03    145
# 0.04    120
# 0.06    102
#        ...
# 0.98      1
# 0.86      1
# 0.92      1
# 0.52      1
# 0.79      1
# Name: PctRecImmig10, Length: 100, dtype: int64
# PctSpeakEnglOnly
# 0.96    117
# 0.95    115
# 0.97     96
# 0.94     95
# 0.92     91
#        ...
# 0.42      1
# 0.08      1
# 1.00      1
# 0.14      1
# 0.02      1
# Name: PctSpeakEnglOnly, Length: 98, dtype: int64
# PctNotSpeakEnglWell
# 0.03    244
# 0.04    228
# 0.02    180
# 0.05    135
# 0.06    123
#        ...
# 0.76      1
# 0.83      1
# 0.91      1
# 0.81      1
# 0.80      1
# Name: PctNotSpeakEnglWell, Length: 94, dtype: int64
# PctLargHouseFam
# 0.17    95
# 0.20    93
# 0.19    93
# 0.14    91
# 0.18    89
#         ..
# 0.90     1
# 0.83     1
# 0.87     1
# 0.88     1
# 0.72     1
# Name: PctLargHouseFam, Length: 99, dtype: int64
# PctLargHouseOccup
# 0.19    111
# 0.17    102
# 0.15    102
# 0.21     90
# 0.18     88
#        ...
# 0.91      1
# 0.61      1
# 0.86      1
# 0.92      1
# 0.72      1
# Name: PctLargHouseOccup, Length: 96, dtype: int64
# PersPerOccupHous
# 0.37    73
# 0.36    72
# 0.38    66
# 0.40    61
# 0.34    61
#         ..
# 0.06     1
# 0.83     1
# 0.87     1
# 0.04     1
# 0.08     1
# Name: PersPerOccupHous, Length: 96, dtype: int64
# PersPerOwnOccHous
# 0.45    77
# 0.47    74
# 0.41    67
# 0.43    66
# 0.40    61
#         ..
# 0.16     1
# 0.11     1
# 0.95     1
# 0.13     1
# 0.07     1
# Name: PersPerOwnOccHous, Length: 94, dtype: int64
# PersPerRentOccHous
# 0.32    67
# 0.30    65
# 0.29    64
# 0.36    63
# 0.37    62
#         ..
# 0.00     1
# 0.96     1
# 0.03     1
# 0.04     1
# 0.94     1
# Name: PersPerRentOccHous, Length: 98, dtype: int64
# PctPersOwnOccup
# 0.54    51
# 0.52    49
# 0.57    48
# 0.59    46
# 0.55    45
#         ..
# 0.16     1
# 0.11     1
# 0.01     1
# 0.07     1
# 0.02     1
# Name: PctPersOwnOccup, Length: 100, dtype: int64
# PctPersDenseHous
# 0.06    142
# 0.04    126
# 0.05    123
# 0.03    103
# 0.07     97
#        ...
# 0.57      1
# 0.79      1
# 0.97      1
# 0.92      1
# 0.66      1
# Name: PctPersDenseHous, Length: 94, dtype: int64
# PctHousLess3BR
# 0.55    75
# 0.53    75
# 0.51    63
# 0.57    58
# 0.58    56
#         ..
# 0.01     1
# 0.98     1
# 0.03     1
# 0.97     1
# 0.92     1
# Name: PctHousLess3BR, Length: 100, dtype: int64
# MedNumBR
# 0.5    1201
# 0.0     766
# 1.0      27
# Name: MedNumBR, dtype: int64
# HousVacant
# 0.01    440
# 0.02    358
# 0.03    237
# 0.04    174
# 0.05    116
#        ...
# 0.74      1
# 0.60      1
# 0.66      1
# 0.52      1
# 0.45      1
# Name: HousVacant, Length: 70, dtype: int64
# PctHousOccup
# 0.88    73
# 0.83    73
# 0.84    69
# 0.89    66
# 0.81    59
#         ..
# 0.11     1
# 0.05     1
# 0.16     1
# 0.19     1
# 0.21     1
# Name: PctHousOccup, Length: 92, dtype: int64
# PctHousOwnOcc
# 0.52    57
# 0.47    54
# 0.48    54
# 0.50    53
# 0.55    52
#         ..
# 0.11     2
# 1.00     2
# 0.10     1
# 0.04     1
# 0.05     1
# Name: PctHousOwnOcc, Length: 99, dtype: int64
# PctVacantBoarded
# 0.00    115
# 0.03     91
# 0.05     89
# 0.04     81
# 0.10     79
#        ...
# 0.67      1
# 0.94      1
# 0.99      1
# 0.78      1
# 0.89      1
# Name: PctVacantBoarded, Length: 97, dtype: int64
# PctVacMore6Mos
# 0.44    52
# 0.37    48
# 0.29    46
# 0.43    45
# 0.47    44
#         ..
# 0.00     1
# 0.06     1
# 0.96     1
# 0.95     1
# 0.04     1
# Name: PctVacMore6Mos, Length: 98, dtype: int64
# MedYrHousBuilt
# 0.00    117
# 0.52     91
# 0.48     81
# 0.54     77
# 0.50     75
# 0.67     75
# 0.56     71
# 0.40     71
# 0.65     67
# 0.63     64
# 0.71     64
# 0.73     63
# 0.60     62
# 0.38     60
# 0.58     59
# 0.42     55
# 0.35     54
# 0.69     53
# 0.75     51
# 0.46     51
# 0.44     49
# 0.31     43
# 0.77     41
# 0.79     41
# 0.33     39
# 0.81     36
# 0.25     33
# 0.29     31
# 0.27     28
# 0.21     26
# 0.83     26
# 0.88     26
# 0.13     24
# 0.17     23
# 0.23     21
# 0.19     18
# 0.85     16
# 0.15     16
# 0.04     14
# 0.90     13
# 0.92     10
# 0.06     10
# 0.08     10
# 0.10      9
# 0.96      9
# 0.94      8
# 0.02      8
# 0.98      3
# 1.00      2
# Name: MedYrHousBuilt, dtype: int64
# PctHousNoPhone
# 0.01    98
# 0.03    93
# 0.02    91
# 0.05    81
# 0.04    74
#         ..
# 0.91     1
# 0.98     1
# 0.85     1
# 0.84     1
# 0.89     1
# Name: PctHousNoPhone, Length: 99, dtype: int64
# PctWOFullPlumb
# 0.00    133
# 0.11     79
# 0.07     69
# 0.13     68
# 0.16     63
#        ...
# 0.79      1
# 0.90      1
# 0.81      1
# 0.93      1
# 0.78      1
# Name: PctWOFullPlumb, Length: 91, dtype: int64
# OwnOccLowQuart
# 0.09    100
# 0.07     78
# 0.06     77
# 0.05     71
# 0.10     71
#        ...
# 0.96      1
# 0.87      1
# 0.98      1
# 0.94      1
# 0.93      1
# Name: OwnOccLowQuart, Length: 99, dtype: int64
# OwnOccMedVal
# 0.08    84
# 0.05    83
# 0.10    83
# 0.09    80
# 0.07    78
#         ..
# 0.73     1
# 0.84     1
# 0.86     1
# 0.94     1
# 0.91     1
# Name: OwnOccMedVal, Length: 100, dtype: int64
# OwnOccHiQuart
# 0.08    122
# 0.09    105
# 0.07     82
# 0.13     82
# 0.11     75
#        ...
# 0.90      1
# 0.00      1
# 0.75      1
# 0.92      1
# 0.94      1
# Name: OwnOccHiQuart, Length: 98, dtype: int64
# RentLowQ
# 0.13    53
# 0.23    50
# 0.12    48
# 0.10    43
# 0.20    43
#         ..
# 0.94     2
# 0.96     2
# 0.92     2
# 0.97     1
# 0.90     1
# Name: RentLowQ, Length: 101, dtype: int64
# RentMedian
# 0.19    53
# 0.20    48
# 0.26    47
# 0.14    47
# 0.17    46
#         ..
# 0.00     1
# 0.92     1
# 0.99     1
# 0.03     1
# 0.02     1
# Name: RentMedian, Length: 99, dtype: int64
# RentHighQ
# 1.00    74
# 0.26    57
# 0.14    55
# 0.16    53
# 0.24    46
#         ..
# 0.99     3
# 0.97     3
# 0.03     2
# 0.00     1
# 0.04     1
# Name: RentHighQ, Length: 99, dtype: int64
# MedRent
# 0.17    65
# 0.21    50
# 0.15    50
# 0.23    50
# 0.20    49
#         ..
# 0.00     1
# 0.04     1
# 0.03     1
# 0.88     1
# 0.90     1
# Name: MedRent, Length: 100, dtype: int64
# MedRentPctHousInc
# 0.40    82
# 0.38    72
# 0.37    62
# 0.51    60
# 0.55    60
#         ..
# 0.05     1
# 0.12     1
# 0.96     1
# 0.98     1
# 0.97     1
# Name: MedRentPctHousInc, Length: 95, dtype: int64
# MedOwnCostPctInc
# 0.41    66
# 0.54    66
# 0.51    57
# 0.49    52
# 0.46    49
#         ..
# 0.01     1
# 0.97     1
# 0.05     1
# 0.90     1
# 0.88     1
# Name: MedOwnCostPctInc, Length: 97, dtype: int64
# MedOwnCostPctIncNoMtg
# 0.24    76
# 0.22    72
# 0.28    67
# 0.37    67
# 0.31    65
#         ..
# 0.00     2
# 0.83     2
# 0.99     1
# 0.04     1
# 0.06     1
# Name: MedOwnCostPctIncNoMtg, Length: 70, dtype: int64
# NumInShelters
# 0.00    1260
# 0.01     248
# 0.02      90
# 0.03      83
# 0.04      55
# 0.05      39
# 0.06      29
# 0.07      23
# 0.08      15
# 1.00      11
# 0.12      11
# 0.09      10
# 0.13      10
# 0.17      10
# 0.15       9
# 0.11       9
# 0.10       9
# 0.18       7
# 0.14       6
# 0.20       5
# 0.21       3
# 0.34       3
# 0.41       3
# 0.16       3
# 0.23       3
# 0.32       3
# 0.52       2
# 0.24       2
# 0.30       2
# 0.25       2
# 0.35       2
# 0.39       2
# 0.31       2
# 0.27       2
# 0.19       2
# 0.67       1
# 0.47       1
# 0.40       1
# 0.59       1
# 0.29       1
# 0.68       1
# 0.62       1
# 0.46       1
# 0.91       1
# 0.26       1
# 0.54       1
# 0.75       1
# 0.58       1
# 0.22       1
# 0.70       1
# 0.79       1
# 0.48       1
# 0.28       1
# 0.33       1
# Name: NumInShelters, dtype: int64
# NumStreet
# 0.00    1597
# 0.01     105
# 0.02      54
# 0.03      39
# 0.04      24
# 0.06      22
# 0.05      19
# 0.08      12
# 0.07      12
# 0.09       9
# 1.00       9
# 0.11       6
# 0.14       6
# 0.10       5
# 0.15       5
# 0.22       5
# 0.19       4
# 0.28       3
# 0.54       3
# 0.61       3
# 0.13       3
# 0.24       3
# 0.20       3
# 0.30       3
# 0.12       3
# 0.31       3
# 0.23       2
# 0.29       2
# 0.16       2
# 0.33       2
# 0.17       2
# 0.50       2
# 0.26       2
# 0.89       1
# 0.34       1
# 0.32       1
# 0.38       1
# 0.63       1
# 0.65       1
# 0.21       1
# 0.25       1
# 0.27       1
# 0.58       1
# 0.53       1
# 0.69       1
# 0.37       1
# 0.35       1
# 0.36       1
# 0.67       1
# 0.85       1
# 0.80       1
# 0.84       1
# 0.62       1
# Name: NumStreet, dtype: int64
# PctForeignBorn
# 0.03    110
# 0.04    102
# 0.05     90
# 0.02     88
# 0.07     78
#        ...
# 0.96      1
# 0.76      1
# 0.89      1
# 0.91      1
# 0.84      1
# Name: PctForeignBorn, Length: 96, dtype: int64
# PctBornSameState
# 0.78    52
# 0.71    48
# 0.79    47
# 0.77    44
# 0.75    43
#         ..
# 0.05     2
# 0.07     2
# 0.11     2
# 0.08     1
# 0.04     1
# Name: PctBornSameState, Length: 99, dtype: int64
# PctSameHouse85
# 0.59    55
# 0.61    52
# 0.54    51
# 0.53    51
# 0.55    48
#         ..
# 0.95     2
# 0.94     2
# 0.10     2
# 0.04     1
# 1.00     1
# Name: PctSameHouse85, Length: 99, dtype: int64
# PctSameCity85
# 0.74    57
# 0.77    55
# 0.73    54
# 0.67    51
# 0.72    51
#         ..
# 0.04     1
# 0.07     1
# 0.13     1
# 0.09     1
# 1.00     1
# Name: PctSameCity85, Length: 100, dtype: int64
# PctSameState85
# 0.79    75
# 0.76    68
# 0.81    63
# 0.75    62
# 0.78    60
#         ..
# 0.97     1
# 0.20     1
# 1.00     1
# 0.01     1
# 0.96     1
# Name: PctSameState85, Length: 97, dtype: int64
# LemasSwornFT
# ?       1675
# 0.02      80
# 0.01      79
# 0.03      37
# 0.04      25
# 0.05      14
# 0.07      14
# 0.06       7
# 0.08       6
# 0.14       4
# 1          4
# 0.12       4
# 0.13       4
# 0.09       3
# 0.3        3
# 0          3
# 0.15       3
# 0.1        3
# 0.16       2
# 0.24       2
# 0.2        2
# 0.25       2
# 0.17       2
# 0.11       1
# 0.42       1
# 0.21       1
# 0.29       1
# 0.18       1
# 0.22       1
# 0.28       1
# 0.58       1
# 0.54       1
# 0.34       1
# 0.38       1
# 0.41       1
# 0.45       1
# 0.19       1
# 0.63       1
# 0.39       1
# Name: LemasSwornFT, dtype: int64
# LemasSwFTPerPop
# ?       1675
# 0.2       19
# 0.1       19
# 0.15      18
# 0.16      16
# 0.19      16
# 0.14      15
# 0.18      15
# 0.17      15
# 0.13      14
# 0.25      13
# 0.12      12
# 0.09      12
# 0.21      11
# 0.11      10
# 0.28      10
# 0.26       9
# 0.08       8
# 0.27       7
# 0.24       7
# 0.22       7
# 1          5
# 0.23       5
# 0.33       4
# 0.3        4
# 0.35       4
# 0.02       3
# 0.43       3
# 0.38       3
# 0.29       3
# 0.68       2
# 0.5        2
# 0.37       2
# 0.03       2
# 0.31       2
# 0.39       2
# 0.32       2
# 0.07       2
# 0.4        2
# 0.64       1
# 0.85       1
# 0.83       1
# 0.34       1
# 0.41       1
# 0.04       1
# 0.67       1
# 0.98       1
# 0.72       1
# 0.06       1
# 0          1
# 0.05       1
# 0.55       1
# 0.42       1
# Name: LemasSwFTPerPop, dtype: int64
# LemasSwFTFieldOps
# ?       1675
# 0.98      81
# 0.97      79
# 0.96      35
# 0.95      26
# 0.93      12
# 0.94      11
# 0.92      10
# 0.91       7
# 0.87       6
# 0.99       5
# 0.85       5
# 0.83       4
# 0          4
# 0.86       3
# 0.89       3
# 0.9        3
# 0.81       2
# 0.84       2
# 0.8        2
# 0.67       2
# 0.75       2
# 0.63       2
# 0.82       2
# 0.53       1
# 0.49       1
# 0.64       1
# 0.37       1
# 0.61       1
# 0.72       1
# 0.55       1
# 1          1
# 0.88       1
# 0.73       1
# 0.76       1
# Name: LemasSwFTFieldOps, dtype: int64
# LemasSwFTFieldPerPop
# ?       1675
# 0.19      17
# 0.14      17
# 0.21      16
# 0.2       15
# 0.32      14
# 0.13      14
# 0.17      14
# 0.12      14
# 0.16      13
# 0.25      12
# 0.23      12
# 0.18      11
# 0.27      11
# 0.22      10
# 0.26      10
# 0.24       9
# 0.15       9
# 0.29       7
# 0.3        7
# 0.1        7
# 0.28       6
# 0.33       5
# 0.36       5
# 1          5
# 0.11       5
# 0.04       4
# 0.31       4
# 0.42       3
# 0.41       3
# 0.39       3
# 0.38       3
# 0.45       3
# 0.03       3
# 0.57       2
# 0.47       2
# 0.46       2
# 0.37       2
# 0.08       2
# 0.01       2
# 0.51       1
# 0.56       1
# 0.55       1
# 0.65       1
# 0.44       1
# 0          1
# 0.06       1
# 0.8        1
# 0.86       1
# 0.88       1
# 0.34       1
# 0.63       1
# 0.43       1
# 0.48       1
# 0.4        1
# 0.49       1
# Name: LemasSwFTFieldPerPop, dtype: int64
# LemasTotalReq
# ?       1675
# 0.02      55
# 0.03      49
# 0.01      32
# 0.04      29
# 0.05      26
# 0.06      17
# 0.07      14
# 0.08      10
# 0.1        8
# 0          7
# 0.09       7
# 0.11       5
# 0.26       4
# 0.18       4
# 1          4
# 0.16       4
# 0.13       3
# 0.32       3
# 0.15       3
# 0.17       3
# 0.28       3
# 0.23       2
# 0.2        2
# 0.29       2
# 0.24       2
# 0.74       2
# 0.33       2
# 0.42       1
# 0.5        1
# 0.3        1
# 0.43       1
# 0.4        1
# 0.49       1
# 0.14       1
# 0.52       1
# 0.58       1
# 0.44       1
# 0.35       1
# 0.12       1
# 0.78       1
# 0.45       1
# 0.31       1
# 0.63       1
# 0.66       1
# Name: LemasTotalReq, dtype: int64
# LemasTotReqPerPop
# ?       1675
# 0.14      23
# 0.17      20
# 0.13      20
# 0.12      17
# 0.19      16
# 0.18      15
# 0.15      14
# 0.08      13
# 0.1       12
# 0.11      11
# 0.21      10
# 0.2        9
# 0.22       9
# 0.09       8
# 0.23       8
# 0.26       7
# 0.25       7
# 0.07       6
# 0.28       5
# 1          5
# 0.02       5
# 0.05       5
# 0.34       5
# 0.29       4
# 0.24       4
# 0.32       4
# 0.27       4
# 0.4        4
# 0.3        3
# 0.38       3
# 0.06       3
# 0.31       3
# 0.37       3
# 0.36       3
# 0.42       2
# 0.84       2
# 0          2
# 0.46       2
# 0.43       2
# 0.16       2
# 0.04       1
# 0.03       1
# 0.35       1
# 0.41       1
# 0.47       1
# 0.49       1
# 0.54       1
# 0.58       1
# 0.72       1
# 0.6        1
# 0.52       1
# 0.77       1
# 0.45       1
# 0.48       1
# 0.69       1
# 0.53       1
# 0.61       1
# 0.39       1
# 0.51       1
# Name: LemasTotReqPerPop, dtype: int64
# PolicReqPerOffic
# ?       1675
# 0.23      15
# 0.25      14
# 0.24      13
# 0.26      12
#         ...
# 0.74       1
# 0.78       1
# 0.64       1
# 0.12       1
# 0.86       1
# Name: PolicReqPerOffic, Length: 76, dtype: int64
# PolicPerPop
# ?       1675
# 0.2       19
# 0.1       19
# 0.15      18
# 0.16      16
# 0.19      16
# 0.14      15
# 0.18      15
# 0.17      15
# 0.13      14
# 0.25      13
# 0.12      12
# 0.09      12
# 0.21      11
# 0.11      10
# 0.26       9
# 0.28       9
# 0.08       8
# 0.27       7
# 0.24       7
# 0.22       7
# 1          5
# 0.23       5
# 0.33       4
# 0.3        4
# 0.29       4
# 0.35       4
# 0.02       3
# 0.43       3
# 0.38       3
# 0.68       2
# 0.5        2
# 0.37       2
# 0.03       2
# 0.31       2
# 0.39       2
# 0.32       2
# 0.07       2
# 0.4        2
# 0.64       1
# 0.85       1
# 0.83       1
# 0.34       1
# 0.41       1
# 0.04       1
# 0.67       1
# 0.98       1
# 0.72       1
# 0.06       1
# 0          1
# 0.05       1
# 0.55       1
# 0.42       1
# Name: PolicPerPop, dtype: int64
# RacialMatchCommPol
# ?       1675
# 0.78      12
# 0.77      10
# 0.95      10
# 0.94      10
#         ...
# 0.35       1
# 0.41       1
# 0.17       1
# 0.39       1
# 0.27       1
# Name: RacialMatchCommPol, Length: 77, dtype: int64
# PctPolicWhite
# ?       1675
# 0.92      11
# 0.97      11
# 0.72      11
# 0.79      10
#         ...
# 0.27       1
# 0.1        1
# 0.47       1
# 0.16       1
# 0.43       1
# Name: PctPolicWhite, Length: 75, dtype: int64
# PctPolicBlack
# ?       1675
# 0         23
# 0.02      18
# 0.04      17
# 0.06      17
#         ...
# 0.91       1
# 0.66       1
# 0.48       1
# 0.68       1
# 0.4        1
# Name: PctPolicBlack, Length: 74, dtype: int64
# PctPolicHisp
# ?       1675
# 0         72
# 0.02      22
# 0.04      21
# 0.03      18
# 0.07      16
# 0.01      16
# 0.16      12
# 0.09      10
# 0.06      10
# 0.05       9
# 1          6
# 0.11       6
# 0.19       6
# 0.14       5
# 0.23       5
# 0.1        5
# 0.28       5
# 0.3        4
# 0.13       4
# 0.17       4
# 0.31       4
# 0.08       4
# 0.12       4
# 0.27       3
# 0.4        3
# 0.46       3
# 0.33       3
# 0.15       3
# 0.29       3
# 0.34       3
# 0.42       2
# 0.83       2
# 0.39       2
# 0.21       2
# 0.43       2
# 0.53       2
# 0.38       1
# 0.54       1
# 0.26       1
# 0.44       1
# 0.65       1
# 0.67       1
# 0.2        1
# 0.24       1
# 0.36       1
# 0.52       1
# 0.47       1
# 0.32       1
# 0.18       1
# 0.22       1
# 0.55       1
# 0.57       1
# 0.9        1
# 0.25       1
# Name: PctPolicHisp, dtype: int64
# PctPolicAsian
# ?       1675
# 0        189
# 1          8
# 0.12       8
# 0.05       7
# 0.15       6
# 0.04       6
# 0.08       5
# 0.06       5
# 0.13       5
# 0.11       4
# 0.07       4
# 0.14       4
# 0.1        4
# 0.09       4
# 0.03       3
# 0.18       3
# 0.16       3
# 0.26       3
# 0.8        2
# 0.21       2
# 0.01       2
# 0.22       2
# 0.59       2
# 0.3        2
# 0.35       2
# 0.19       2
# 0.52       2
# 0.32       2
# 0.23       2
# 0.49       2
# 0.38       2
# 0.17       2
# 0.37       2
# 0.51       2
# 0.75       1
# 0.56       1
# 0.93       1
# 0.67       1
# 0.39       1
# 0.48       1
# 0.31       1
# 0.72       1
# 0.69       1
# 0.98       1
# 0.27       1
# 0.4        1
# 0.81       1
# 0.74       1
# 0.29       1
# 0.6        1
# Name: PctPolicAsian, dtype: int64
# PctPolicMinor
# ?       1675
# 0.07      14
# 0.13      12
# 0.1       11
# 0.01      11
#         ...
# 0.66       1
# 0.44       1
# 0.93       1
# 0.88       1
# 0.47       1
# Name: PctPolicMinor, Length: 73, dtype: int64
# OfficAssgnDrugUnits
# ?       1675
# 0.03      48
# 0.02      47
# 0.04      38
# 0.01      31
# 0.05      25
# 0.07      22
# 0.11      13
# 0         10
# 0.06      10
# 0.08      10
# 0.1       10
# 0.12       8
# 0.15       6
# 0.18       6
# 0.16       6
# 0.09       4
# 0.19       4
# 0.13       3
# 0.17       3
# 0.26       3
# 1          3
# 0.33       1
# 0.22       1
# 0.73       1
# 0.37       1
# 0.49       1
# 0.14       1
# 0.44       1
# 0.45       1
# 0.4        1
# Name: OfficAssgnDrugUnits, dtype: int64
# NumKindsDrugsSeiz
# ?       1675
# 0.57      54
# 0.5       43
# 0.64      41
# 0.43      35
# 0.36      27
# 0.79      22
# 0.71      22
# 0.93      21
# 0.29      19
# 0.86      13
# 0.21       8
# 0.14       7
# 0.07       3
# 0          2
# 1          2
# Name: NumKindsDrugsSeiz, dtype: int64
# PolicAveOTWorked
# ?       1675
# 0.19      12
# 0.1       10
# 0.14      10
# 0.17       9
#         ...
# 0.4        1
# 0.99       1
# 0.75       1
# 0.63       1
# 0.97       1
# Name: PolicAveOTWorked, Length: 78, dtype: int64
# LandArea
# 0.01    323
# 0.02    311
# 0.03    263
# 0.04    190
# 0.05    143
#        ...
# 0.64      1
# 0.51      1
# 0.46      1
# 0.48      1
# 0.95      1
# Name: LandArea, Length: 61, dtype: int64
# PopDens
# 0.09    86
# 0.12    79
# 0.14    74
# 0.08    73
# 0.13    72
#         ..
# 0.99     1
# 0.87     1
# 0.76     1
# 0.94     1
# 0.78     1
# Name: PopDens, Length: 96, dtype: int64
# PctUsePubTrans
# 0.01    220
# 0.00    183
# 0.02    164
# 0.03    117
# 0.04    111
#        ...
# 0.83      1
# 0.60      1
# 0.84      1
# 0.91      1
# 0.93      1
# Name: PctUsePubTrans, Length: 98, dtype: int64
# PolicCars
# ?       1675
# 0.02      27
# 0.04      26
# 0.05      26
# 0.06      23
#         ...
# 0.36       1
# 0.62       1
# 0.28       1
# 0.47       1
# 0.45       1
# Name: PolicCars, Length: 64, dtype: int64
# PolicOperBudg
# ?       1675
# 0.02      69
# 0.01      52
# 0.03      48
# 0.04      31
# 0.05      20
# 0.06      12
# 0.07      10
# 0          9
# 0.09       7
# 0.08       7
# 0.15       6
# 0.1        4
# 0.28       4
# 0.12       4
# 0.13       3
# 1          3
# 0.19       3
# 0.34       3
# 0.17       2
# 0.18       2
# 0.62       2
# 0.14       2
# 0.58       1
# 0.35       1
# 0.16       1
# 0.32       1
# 0.27       1
# 0.24       1
# 0.36       1
# 0.47       1
# 0.26       1
# 0.2        1
# 0.64       1
# 0.3        1
# 0.72       1
# 0.52       1
# 0.41       1
# 0.38       1
# Name: PolicOperBudg, dtype: int64
# LemasPctPolicOnPatr
# ?       1675
# 0.74      13
# 0.84      13
# 0.79      13
# 0.8       11
#         ...
# 0.19       1
# 0.38       1
# 0.1        1
# 0.99       1
# 0.39       1
# Name: LemasPctPolicOnPatr, Length: 73, dtype: int64
# LemasGangUnitDeploy
# ?      1675
# 0       126
# 0.5     105
# 1        88
# Name: LemasGangUnitDeploy, dtype: int64
# LemasPctOfficDrugUn
# 0.00    1685
# 1.00      48
# 0.51       9
# 0.36       9
# 0.61       8
#         ...
# 0.10       1
# 0.90       1
# 0.28       1
# 0.83       1
# 0.05       1
# Name: LemasPctOfficDrugUn, Length: 80, dtype: int64
# PolicBudgPerPop
# ?       1675
# 0.12      22
# 0.1       20
# 0.14      18
# 0.15      17
# 0.16      17
# 0.13      16
# 0.11      16
# 0.19      16
# 0.09      15
# 0.18      14
# 0.22      11
# 0.21      11
# 0.08      10
# 0.23       9
# 0.17       9
# 0.27       8
# 0.2        8
# 0.07       7
# 1          6
# 0.25       6
# 0.05       5
# 0.29       5
# 0.32       4
# 0.24       4
# 0.06       4
# 0.31       3
# 0.02       3
# 0.26       3
# 0.04       3
# 0.28       3
# 0.34       3
# 0          2
# 0.36       2
# 0.35       2
# 0.48       1
# 0.03       1
# 0.99       1
# 0.44       1
# 0.3        1
# 0.76       1
# 0.73       1
# 0.69       1
# 0.56       1
# 0.52       1
# 0.54       1
# 0.71       1
# 0.33       1
# 0.82       1
# 0.01       1
# 0.51       1
# 0.4        1
# Name: PolicBudgPerPop, dtype: int64
# ViolentCrimesPerPop
# 0.03    104
# 0.04     92
# 0.06     86
# 0.05     80
# 0.02     74
#        ...
# 0.79      2
# 0.77      1
# 0.89      1
# 0.94      1
# 0.96      1
# Name: ViolentCrimesPerPop, Length: 98, dtype: int64

# %% [markdown]
# ## Feature selection

# %%
crime_df.shape
# Out:
# (1994, 101)

# %%
crime_df.head()
# Out:
#    state  population  householdsize  racepctblack  racePctWhite  racePctAsian  \
# 0      8        0.19           0.33          0.02          0.90          0.12
# 1     53        0.00           0.16          0.12          0.74          0.45
# 2     24        0.00           0.42          0.49          0.56          0.17
# 3     34        0.04           0.77          1.00          0.08          0.12
# 4     42        0.01           0.55          0.02          0.95          0.09
#
#    racePctHisp  agePct12t21  agePct12t29  agePct16t24  ...  PctForeignBorn  \
# 0         0.17         0.34         0.47         0.29  ...            0.12
# 1         0.07         0.26         0.59         0.35  ...            0.21
# 2         0.04         0.39         0.47         0.28  ...            0.14
# 3         0.10         0.51         0.50         0.34  ...            0.19
# 4         0.05         0.38         0.38         0.23  ...            0.11
#
#    PctBornSameState  PctSameHouse85  PctSameCity85  PctSameState85  LandArea  \
# 0              0.42            0.50           0.51            0.64      0.12
# 1              0.50            0.34           0.60            0.52      0.02
# 2              0.49            0.54           0.67            0.56      0.01
# 3              0.30            0.73           0.64            0.65      0.02
# 4              0.72            0.64           0.61            0.53      0.04
#
#    PopDens  PctUsePubTrans  LemasPctOfficDrugUn  ViolentCrimesPerPop
# 0     0.26            0.20                 0.32                 0.20
# 1     0.12            0.45                 0.00                 0.67
# 2     0.21            0.02                 0.00                 0.43
# 3     0.39            0.28                 0.00                 0.12
# 4     0.09            0.02                 0.00                 0.03
#
# [5 rows x 101 columns]

# %%
X = (crime_df.iloc[:,:crime_df.shape[1]-1]).to_numpy().flatten().reshape(crime_df.shape[0],-1)
y = crime_df.iloc[:,crime_df.shape[1]-1:crime_df.shape[1]].to_numpy().flatten()

# %% [markdown]
# ## Scaling features

# %%
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %% [markdown]
# ## Importing libraries

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Define training and plotting methods

# %%
def train_estimators(X, y, estimator_type, param_name, param_vals, **kwargs):
    """
    
    Trains multiple instances of `estimator_type` on (X, y) by setting argument
    named `param_name` to each value in `param_vals`. Prints a message before
    training each instance. Returns the list of trained estimators.
    
    For example:
    
       >>> train_estimators(X, y, DecisionTreeClassifier, 'max_depth', [1, 5, 10],
                            splitter='random', random_state=0)
    
       Training DecisionTreeClassifier(max_depth=1, random_state=0, splitter='random')...
       Training DecisionTreeClassifier(max_depth=5, random_state=0, splitter='random')...
       Training DecisionTreeClassifier(max_depth=10, random_state=0, splitter='random')...

       [DecisionTreeClassifier(max_depth=1, random_state=0, splitter='random'),
        DecisionTreeClassifier(max_depth=5, random_state=0, splitter='random'),
        DecisionTreeClassifier(max_depth=10, random_state=0, splitter='random')] 
    """
    # Your implementation here. Aim for 5-10 lines.
    estimators = []
    extra_params = ''

    for arg in kwargs:
        extra_params = extra_params + str(arg) + '=' + str(kwargs[arg])+ ', ' 
        
    for val in param_vals:
        estimator = estimator_type(**{param_name : val}, **kwargs).fit(X,y)
        estimators.append(estimator)
        print('Training' + ' ' +str(estimator.__class__.__name__) +'(' + str(param_name) + '=' + str(val) + ', ' + extra_params + ')...')

    return estimators;

# %%
def plot_estimator_scores(estimators, param_name, param_vals):
    """
    Plots the training, validation, and testing scores of a list of estimators,
    where `param_name` and `param_vals` are the same as for `train_estimators`.
    The estimator with best validation score will be highlighted with an 'x'.
    """
    # Your implementation here. Use as many lines as you need.

    N = len(param_vals)
    x2 = np.arange(N)
    
    training_scores = score_estimators(X_train, y_train, estimators)
    test_scores = score_estimators(X_test, y_test, estimators)
    val_scores = score_estimators(X_val, y_val, estimators)
    
    val_score_index = val_scores.index(np.max(val_scores))
    
    plt.plot(x2, training_scores, '-ok', color = 'g', label = 'train')
    plt.plot(x2, val_scores, '-ok',color = 'r', label = 'val') 
    plt.plot(x2, test_scores, linestyle='dashed', color = "k",label = 'test' )
    plt.plot(4,np.max(val_scores), marker = 'x', color = 'r', markersize = 16)
    
    plt.legend()
    plt.xticks(x2,param_vals)
    plt.ylim(ymin=0)
    plt.title(str(estimators[0].__class__.__name__) +' '+ 'score vs '  + str(param_name))
    plt.text(4, 0.31,'train = ' + str(training_scores[val_score_index])[:5], color='green')
    plt.text(4, 0.24, 'val = ' + str(val_scores[val_score_index])[:5], color='red')
    plt.text(4, 0.17, 'test = ' + str(test_scores[val_score_index])[:5])
    plt.figure()

# %%
def score_estimators(X, y, estimators):
    """Scores each estimator on (X, y), returning a list of scores."""
    scores = []
    for estimator in estimators:
        scores.append(estimator.score(X,y))
    return scores

# %% [markdown]
# # Training various classifiers
# ## Splitting the data into training, testing, and validation sets

# %%
# Your code here. Aim for 2-3 lines.
X_train, X_test, y_train, y_test= train_test_split(X_scaled, y, train_size=0.80, test_size = 0.20, random_state=0)
X_train, X_val, y_train, y_val= train_test_split(X_train, y_train, train_size=0.75, test_size = 0.25, random_state=0)

# %% [markdown]
# ## Linear Regression

# %%
LinearRegressionEstimators = LinearRegression().fit(X_scaled, y)
LR_train_score = LinearRegressionEstimators.score(X_train, y_train)
LR_test_score = LinearRegressionEstimators.score(X_test, y_test)
LR_val_score = LinearRegressionEstimators.score(X_val, y_val)
LR_scores = [LR_train_score,LR_test_score,LR_val_score]
print(LR_scores)
# Out:
# [0.6917049838453979, 0.7028756333301016, 0.696445656053672]

# %% [markdown]
# ## SVM Regression

# %%
SVMEstimator = train_estimators(X_train, y_train, sklearn.svm.SVR,
                                   'C', [0.01, 0.1,1.0,10.0,100.0,1000.0],gamma=0.0001,max_iter=10000)
plot_estimator_scores(SVMEstimator,'C',[0.01, 0.1,1.0,10.0,100.0,1000.0])
# Out:
# Training SVR(C=0.01, gamma=0.0001, max_iter=10000, )...
# Training SVR(C=0.1, gamma=0.0001, max_iter=10000, )...
# Training SVR(C=1.0, gamma=0.0001, max_iter=10000, )...
# Training SVR(C=10.0, gamma=0.0001, max_iter=10000, )...
# Training SVR(C=100.0, gamma=0.0001, max_iter=10000, )...
# Training SVR(C=1000.0, gamma=0.0001, max_iter=10000, )...
# C:\Users\Luigi\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# <ipython-input-12-b1055e0afb51>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, training_scores, '-ok', color = 'g', label = 'train')
# <ipython-input-12-b1055e0afb51>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, val_scores, '-ok',color = 'r', label = 'val')

# %% [markdown]
# ## Decision Tree Regression

# %%
DecisionTreeEstimators = train_estimators(X_train, y_train, DecisionTreeRegressor,
                                   'max_depth', [1, 5, 10,20,50,100], splitter='random', random_state=0)
plot_estimator_scores(DecisionTreeEstimators,'max_depth',[1, 5, 10,20,50,100])
# Out:
# <ipython-input-12-b1055e0afb51>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, training_scores, '-ok', color = 'g', label = 'train')
# Training DecisionTreeRegressor(max_depth=1, splitter=random, random_state=0, )...
# Training DecisionTreeRegressor(max_depth=5, splitter=random, random_state=0, )...
# Training DecisionTreeRegressor(max_depth=10, splitter=random, random_state=0, )...
# Training DecisionTreeRegressor(max_depth=20, splitter=random, random_state=0, )...
# Training DecisionTreeRegressor(max_depth=50, splitter=random, random_state=0, )...
# Training DecisionTreeRegressor(max_depth=100, splitter=random, random_state=0, )...
# <ipython-input-12-b1055e0afb51>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, val_scores, '-ok',color = 'r', label = 'val')

# %% [markdown]
# ## RandomForest Regressor

# %%
# RandomTreeEstimators = train_estimators(X_train, y_train, sklearn.ensemble.RandomForestClassifier,
#                                    'max_depth', [1, 5, 10,20,50,100], random_state=0)
# plot_estimator_scores(RandomTreeEstimators,'max_depth',[1, 5, 10,20,50,100])

# %% [markdown]
# ## K-nearest Regressor

# %%
KNearestEstimators = train_estimators(X_train, y_train, KNeighborsRegressor,
                                      'weights', ['uniform','distance'],n_neighbors=2)
plot_estimator_scores(KNearestEstimators,'weights', ['uniform','distance'])

KNearestEstimators = train_estimators(X_train, y_train, KNeighborsRegressor,
                                      'algorithm', ['auto', 'ball_tree', 'kd_tree','brute'],n_neighbors=2)
plot_estimator_scores(KNearestEstimators,'algorithm', ['auto', 'ball_tree', 'kd_tree','brute'])
# Out:
# Training KNeighborsRegressor(weights=uniform, n_neighbors=2, )...
# <ipython-input-12-b1055e0afb51>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, training_scores, '-ok', color = 'g', label = 'train')
# <ipython-input-12-b1055e0afb51>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, val_scores, '-ok',color = 'r', label = 'val')
# Training KNeighborsRegressor(weights=distance, n_neighbors=2, )...
# Training KNeighborsRegressor(algorithm=auto, n_neighbors=2, )...
# Training KNeighborsRegressor(algorithm=ball_tree, n_neighbors=2, )...
# Training KNeighborsRegressor(algorithm=kd_tree, n_neighbors=2, )...
# Training KNeighborsRegressor(algorithm=brute, n_neighbors=2, )...
# <ipython-input-12-b1055e0afb51>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, training_scores, '-ok', color = 'g', label = 'train')
# <ipython-input-12-b1055e0afb51>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, val_scores, '-ok',color = 'r', label = 'val')

# %% [markdown]
# ## Ada Boost Regression

# %%
AdaBoostEstimators = train_estimators(X_train, y_train, AdaBoostRegressor,
                                   'n_estimators', [10, 50, 100, 500, 1000, 5000], random_state=0)
plot_estimator_scores(AdaBoostEstimators,'n_estimators',[10, 50, 100, 500, 1000, 5000])
# Out:
# Training AdaBoostRegressor(n_estimators=10, random_state=0, )...
# Training AdaBoostRegressor(n_estimators=50, random_state=0, )...
# Training AdaBoostRegressor(n_estimators=100, random_state=0, )...
# Training AdaBoostRegressor(n_estimators=500, random_state=0, )...
# Training AdaBoostRegressor(n_estimators=1000, random_state=0, )...
# Training AdaBoostRegressor(n_estimators=5000, random_state=0, )...
# <ipython-input-12-b1055e0afb51>:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, training_scores, '-ok', color = 'g', label = 'train')
# <ipython-input-12-b1055e0afb51>:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x2, val_scores, '-ok',color = 'r', label = 'val')

# %% [markdown]
# ## Gaussian Process Regressor

# %%
clf = GaussianProcessRegressor()
NaiveBayesRegressor=clf.fit(X_train, y_train)
NB_test_scores =  NaiveBayesRegressor.score(X_test, y_test)
NB_val_scores =  NaiveBayesRegressor.score(X_val, y_val)
print(NB_val_scores,NB_test_scores)
# Out:
# -1.043493060654424 -0.9775395507144322
